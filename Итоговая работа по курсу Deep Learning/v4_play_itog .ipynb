# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# скачиваем датасет апельсинового сада с малым количеством изображений
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CQL5rwm3Xg5OTOzuPH8L")
project = rf.workspace("fwuit").project("orange-l4geq")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Orange-1 in yolov8:: 100%|██████████| 92/92 [00:00<00:00, 4475.69it/s]

# %%
# скачиваем датасет с апельсиновыми деревьями
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CQL5rwm3Xg5OTOzuPH8L")
project = rf.workspace("1-xjgvf").project("orange-8ywhf")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Orange-5 in yolov8:: 100%|██████████| 10810/10810 [00:13<00:00, 788.83it/s]

# %%
import yaml

def read_and_print_yaml(file_path):
    # Открываем файл и читаем его содержимое
    with open(file_path, 'r') as file:
        data = yaml.safe_load(file)

    # Выводим содержимое файла в нужном формате
    print(f"train: {data['train']}")
    print(f"val: {data['val']}")
    print(f"test: {data['test']}\n")
    print(f"nc: {data['nc']}")
    print(f"names: {data['names']}\n")
    print("roboflow:")
    for key, value in data['roboflow'].items():
        print(f"  {key}: {value}")

# %%
read_and_print_yaml('/content/Orange-5/data.yaml')
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['orange']
#
# roboflow:
#   license: CC BY 4.0
#   project: orange-8ywhf
#   url: https://universe.roboflow.com/1-xjgvf/orange-8ywhf/dataset/5
#   version: 5
#   workspace: 1-xjgvf

# %%
# меняем пути к изображениям на актуальные (необходимо для запуска модели на датасете)
with open('/content/Orange-5/data.yaml', 'r') as file:
    data = yaml.safe_load(file)

# Modify the data
data['train'] = '../train/images'
data['val'] = '../valid/images'

# Save the modified data back to the YAML file
with open('/content/Orange-5/data.yaml', 'w') as file:
    yaml.dump(data, file, default_flow_style=False)

# %%
# проверяем
read_and_print_yaml('/content/Orange-5/data.yaml')
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['orange']
#
# roboflow:
#   license: CC BY 4.0
#   project: orange-8ywhf
#   url: https://universe.roboflow.com/1-xjgvf/orange-8ywhf/dataset/5
#   version: 5
#   workspace: 1-xjgvf

# %%
read_and_print_yaml('/content/Orange-1/data.yaml')
# Out:
# train: Orange-1/train/images
# val: Orange-1/valid/images
# test: ../test/images
#
# nc: 1
# names: ['Oranges']
#
# roboflow:
#   license: CC BY 4.0
#   project: orange-l4geq
#   url: https://universe.roboflow.com/fwuit/orange-l4geq/dataset/1
#   version: 1
#   workspace: fwuit

# %%
# меняем пути к изображениям на актуальные (необходимо для запуска модели на датасете)
with open('/content/Orange-1/data.yaml', 'r') as file:
    data = yaml.safe_load(file)

# Modify the data
data['train'] = '../train/images'
data['val'] = '../valid/images'

# Save the modified data back to the YAML file
with open('/content/Orange-5/data.yaml', 'w') as file:
    yaml.dump(data, file, default_flow_style=False)

# %%
read_and_print_yaml('/content/Orange-1/data.yaml')
# Out:
# train: Orange-1/train/images
# val: Orange-1/valid/images
# test: ../test/images
#
# nc: 1
# names: ['Oranges']
#
# roboflow:
#   license: CC BY 4.0
#   project: orange-l4geq
#   url: https://universe.roboflow.com/fwuit/orange-l4geq/dataset/1
#   version: 1
#   workspace: fwuit

# %%
# скачиваем кадры из целевого фильма
#https://drive.google.com/file/d/1ZZTc9RWx31ebvRD3AfdxOioNMZnSKiwv/view?usp=drive_link

# !pip install -q gdown==4.7.3
# !gdown --quiet 1ZZTc9RWx31ebvRD3AfdxOioNMZnSKiwv -O image_paths_films.zip
# !unzip -q "image_paths_films.zip"

# %%
# скачиваем кадры из целевого фильма
#https://drive.google.com/file/d/1sv1Ufo5b7oM-f-DzFXXPE2CbeYaEEy7Q/view?usp=drive_link

#!pip install -q gdown==4.7.3
# !gdown --quiet 1sv1Ufo5b7oM-f-DzFXXPE2CbeYaEEy7Q -O image_paths_films_3.zip
# !unzip -q "image_paths_films_3.zip"

# %%
# !pip install -q gdown==4.7.3
# !gdown --quiet 15QfuVYGwqoPHy0ldiYxb9H3HPjg3AvPs -O man_orange_farm3--online-audio-convert.com.mp4
# !gdown --quiet 1IYBTrBANRFGPlmmjOgC5KQDxzic6sQ-c -O Многоцелевая_весовая_станция.mp4
#https://drive.google.com/file/d/1IYBTrBANRFGPlmmjOgC5KQDxzic6sQ-c/view?usp=drive_link

# %%
#dir_path = "ves"
# !mkdir ves
#https://drive.google.com/file/d/1Dn1dl1ddAsZxe3ziHfAUZ2XXu-YtD5v0/view?usp=drive_link
# !gdown --quiet 1Dn1dl1ddAsZxe3ziHfAUZ2XXu-YtD5v0 -O best.pt
#https://drive.google.com/file/d/10o71LjhA5a5RuUS-hW92Yi9RamAggi7l/view?usp=drive_link
# !gdown --quiet 10o71LjhA5a5RuUS-hW92Yi9RamAggi7l -O best2.pt
#https://drive.google.com/file/d/1oQWwRDre1CVHSJv-tMrEbItI87wGOGdD/view?usp=drive_link
# !gdown --quiet 1oQWwRDre1CVHSJv-tMrEbItI87wGOGdD -O best3.pt
# Out:
# mkdir: cannot create directory ‘ves’: File exists

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.0/793.0 kB 12.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install supervision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

import supervision as sv
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# необходим для правильного отображения изображений в колабе
from google.colab.patches import cv2_imshow
# Out:
# Ultralytics YOLOv8.2.41 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/78.2 GB disk)

# %% [markdown]
# <font color=green size=3>
# Теперь сделаем предсказания для машины взвешивания, используя веса, полученные после нашего дообучения на датасете искуственно созданном при внедрении апельсинов в другие композиции.
# </font>

# %%
    # Скачиваем наиболее удачные веса для YOLOv8 модели после обучения на датасете с условиями,похожими на целевой фильм
    yolo_model_best2 = YOLO('/content/ves/best2.pt')

# %%
# берем кадры из нашего целевого видео
image_paths_films_3 = [
    '/content/image_paths_films_3/frame0.jpg',
    '/content/image_paths_films_3/frame120.jpg',
    '/content/image_paths_films_3/frame240.jpg',
    '/content/image_paths_films_3/frame60.jpg'
]

# %%
# проверяем, как предсказывает модель после дообучения на искуственном датасете
for img_in in image_paths_films_3:
  results = yolo_model_best2.predict(img_in)
  result = results[0]
  detections = sv.Detections.from_ultralytics(result)

  bounding_box_annotator = sv.BoundingBoxAnnotator()
  label_annotator = sv.LabelAnnotator()

  labels = [
    yolo_model_best2.model.names[class_id]
    for class_id
    in detections.class_id
  ]

  image = cv2.imread(img_in)

  annotated_image = bounding_box_annotator.annotate(
     scene=image, detections=detections)
  annotated_image = label_annotator.annotate(
     scene=annotated_image, detections=detections, labels=labels)

  sv.plot_image(annotated_image)
  for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    if class_id == 'orange' :
      cords = box.xyxy[0].tolist()
      cords = [round(x) for x in cords]
      conf = round(box.conf[0].item(), 2)
      print("Object type:", class_id)
      print("Coordinates:", cords)
      print("Probability:", conf)
      print("---")

# %% [markdown]
# <font color=green size=3>
# Видим, что нейросеть, обученная на искуственно созданном  втором датасете и на этом видео не смогла найти ни одного апельсина.
# <br>
# Видео распознавать нет никакой необходимости.
# <br>
#
# Посмотрим, сможет ли найти на этих кадрах апельсины нейросеть обученная на первом основном датасете с изображениями апельсинового сада.
# </font>

# %%
    # Скачиваем наиболее удачные веса для YOLOv8 модели после обучения на датасете с условиями,похожими на целевой фильм, сбольшим количеством малых изображений
    yolo_model_best = YOLO('/content/ves/best.pt')

# %%
# проверяем, как предсказывает модель после дообучения на искуственном датасете
for img_in in image_paths_films_3:
  results = yolo_model_best.predict(img_in)
  result = results[0]
  detections = sv.Detections.from_ultralytics(result)

  bounding_box_annotator = sv.BoundingBoxAnnotator()
  label_annotator = sv.LabelAnnotator()

  labels = [
    yolo_model_best.model.names[class_id]
    for class_id
    in detections.class_id
  ]

  image = cv2.imread(img_in)

  annotated_image = bounding_box_annotator.annotate(
     scene=image, detections=detections)
  annotated_image = label_annotator.annotate(
     scene=annotated_image, detections=detections, labels=labels)

  sv.plot_image(annotated_image)
  for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    if class_id == 'orange' :
      cords = box.xyxy[0].tolist()
      cords = [round(x) for x in cords]
      conf = round(box.conf[0].item(), 2)
      print("Object type:", class_id)
      print("Coordinates:", cords)
      print("Probability:", conf)
      print("---")

# %% [markdown]
# <font color=green size=3>
# Видим явный прогресс.
# <br>
# Апельсины распознаются, но не все.
# <br>
#
# Посмотрим, сможет ли найти на этих кадрах апельсины нейросеть обученная на третьем малом датасете с изображениями апельсинового сада.
# </font>

# %%
    # Скачиваем наиболее удачные веса для YOLOv8 модели после обучения на датасете с условиями,похожими на целевой фильм и малым количеством больших изображений
    yolo_model_best3 = YOLO('/content/ves/best3.pt')

# %%
# проверяем, как предсказывает модель после дообучения на датасете с малым количеством больших изображений
for img_in in image_paths_films_3:
  results = yolo_model_best3.predict(img_in)
  result = results[0]
  detections = sv.Detections.from_ultralytics(result)

  bounding_box_annotator = sv.BoundingBoxAnnotator()
  label_annotator = sv.LabelAnnotator()

  labels = [
    yolo_model_best3.model.names[class_id]
    for class_id
    in detections.class_id
  ]

  image = cv2.imread(img_in)

  annotated_image = bounding_box_annotator.annotate(
     scene=image, detections=detections)
  annotated_image = label_annotator.annotate(
     scene=annotated_image, detections=detections, labels=labels)

  sv.plot_image(annotated_image)
  for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    if class_id == 'orange' :
      cords = box.xyxy[0].tolist()
      cords = [round(x) for x in cords]
      conf = round(box.conf[0].item(), 2)
      print("Object type:", class_id)
      print("Coordinates:", cords)
      print("Probability:", conf)
      print("---")

# %% [markdown]
# <font color=green size=3>
# Снова ничего не распозналось.
# <br>
# Попробуем скачать просто предобученную модель и распознать эти кадры.
# <br>
# </font>

# %%
        model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 322MB/s]

# %%
# проверяем, как предсказывает просто предобученная модель
for img_in in image_paths_films_3:
  results = model.predict(img_in)
  result = results[0]
  detections = sv.Detections.from_ultralytics(result)

  bounding_box_annotator = sv.BoundingBoxAnnotator()
  label_annotator = sv.LabelAnnotator()

  labels = [
    model.model.names[class_id]
    for class_id
    in detections.class_id
  ]

  image = cv2.imread(img_in)

  annotated_image = bounding_box_annotator.annotate(
     scene=image, detections=detections)
  annotated_image = label_annotator.annotate(
     scene=annotated_image, detections=detections, labels=labels)

  sv.plot_image(annotated_image)
  for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    if class_id == 'orange' :
      cords = box.xyxy[0].tolist()
      cords = [round(x) for x in cords]
      conf = round(box.conf[0].item(), 2)
      print("Object type:", class_id)
      print("Coordinates:", cords)
      print("Probability:", conf)
      print("---")

# %% [markdown]
# <font color=green size=3>
# Снова ничего не распозналось.
# <br>
# Сплошные ложные срабатывания.
# <br>
# Видимо наше изображение невысокого качества, что визуально заметно.
# <br>
# Качество изображения тоже имеет очень существенное значение, так же, как и  разрешение.
# </font>

# %%
# берем кадры из нашего целевого видео
image_paths_films = [
    '/content/image_paths_films/frame10020000.jpg',
    '/content/image_paths_films/frame20040000.jpg',
    '/content/image_paths_films/frame30000000.jpg',
    '/content/image_paths_films/frame4020000.jpg'
]

# %%
# проверяем, как предсказывает нейросеть, дообученная на третьем малом датасете на нашем целевом видео сада.
for img_in in image_paths_films:
  results = yolo_model_best3.predict(img_in)
  result = results[0]
  detections = sv.Detections.from_ultralytics(result)

  bounding_box_annotator = sv.BoundingBoxAnnotator()
  label_annotator = sv.LabelAnnotator()

  labels = [
    yolo_model_best3.model.names[class_id]
    for class_id
    in detections.class_id
  ]

  image = cv2.imread(img_in)

  annotated_image = bounding_box_annotator.annotate(
     scene=image, detections=detections)
  annotated_image = label_annotator.annotate(
     scene=annotated_image, detections=detections, labels=labels)

  sv.plot_image(annotated_image)
  for box in result.boxes:
    class_id = result.names[box.cls[0].item()]
    if class_id == 'orange' :
      cords = box.xyxy[0].tolist()
      cords = [round(x) for x in cords]
      conf = round(box.conf[0].item(), 2)
      print("Object type:", class_id)
      print("Coordinates:", cords)
      print("Probability:", conf)
      print("---")

# %% [markdown]
# <font color=green size=3>
# А теперь распознаем объекты на целевом видео нашего сада с использованием нейросети, дообученной на третьем маалом датасете.
# <br>
# <br>
# </font>

# %%
results_play_best3 = yolo_model_best3.predict(source='/content/man_orange_farm3--online-audio-convert.com.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/614) /content/man_orange_farm3--online-audio-convert.com.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (frame 2/614) /content/man_orange_farm3--online-audio-convert.com.mp4: 384x640 (no detections), 10.7ms
# video 1/1 (frame 3/614) /content/man_orange_farm3--online-audio-convert.com.mp4: 384x640 (no detections), 8.8ms
# ...

# %% [markdown]
# <font color=green size=3>
# Ни на одном кадре ничего не опозналось.
# <br>
# А казалось, что метрики при обучении на третьем датасете были уже хорошие.
# <br>
# Видимо на этом датасете не хватило времени дополнительного обучения нейросети.
# <br>
# По второму "искуственному датасету можно сказать, что искуственные приемы аугментации не помогают ,если не соответствует "фактура" объекта.Даже такой простой объект, как апельсин при кардинальной смене фона перестает детектироваться.
# <br>
# Это подчеркивает важность создания актуального датасета под конкретную задачу.
# </font>

# %%
# скачиваем кадры из целевого фильма, переделанные в формат _1280*720
#https://drive.google.com/file/d/10hslK8FCgG7Kir7r4pepdI_H6Ya4q2oG/view?usp=drive_link

# !pip install -q gdown==4.7.3
# !gdown --quiet 10hslK8FCgG7Kir7r4pepdI_H6Ya4q2oG -O image_paths_films_4.zip
# !unzip -q "image_paths_films_4.zip"

# %%
#https://drive.google.com/file/d/1F93R9C26iYgeZOaighQr4dfcxj5DHQv4/view?usp=sharing

# !pip install -q gdown==4.7.3
# !gdown --quiet 1F93R9C26iYgeZOaighQr4dfcxj5DHQv4 -O сад_1280_720.mp4
